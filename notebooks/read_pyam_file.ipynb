# %%
import pandas as pd

df = pd.read_csv('C:/Users/mencsm/rcmip/rcmip-concentrations-annual-means.csv')

# %%
df.head()
# Out:
#   Model Scenario Region                          Variable Unit Mip_Era  \
# 0   AIM    RCP60  World   Atmospheric Concentrations|C2F6  ppt   CMIP5
# 1   AIM    RCP60  World  Atmospheric Concentrations|C6F14  ppt   CMIP5
# 2   AIM    RCP60  World   Atmospheric Concentrations|CCl4  ppt   CMIP5
# 3   AIM    RCP60  World    Atmospheric Concentrations|CF4  ppt   CMIP5
# 4   AIM    RCP60  World  Atmospheric Concentrations|CFC11  ppt   CMIP5
#
#   Activity_Id  1700  1701  1702  ...        2491        2492        2493  \
# 0  input4MIPs   NaN   NaN   NaN  ...   15.641697   15.641697   15.641697
# 1  input4MIPs   NaN   NaN   NaN  ...    0.318736    0.318736    0.318736
# 2  input4MIPs   NaN   NaN   NaN  ...    0.086548    0.086548    0.086548
# 3  input4MIPs   NaN   NaN   NaN  ...  257.340650  257.340650  257.340650
# 4  input4MIPs   NaN   NaN   NaN  ...    7.301835    7.301835    7.301835
#
#          2494        2495        2496        2497        2498        2499  \
# ...

# %%
df[(df['Region']=='World')&(df['Mip_Era']=='CMIP6')&~(df['Scenario'].str.startswith('historical'))]
# Out:
#               Model Scenario Region                          Variable Unit  \
# 35              AIM   ssp370  World   Atmospheric Concentrations|C2F6  ppt
# 36              AIM   ssp370  World   Atmospheric Concentrations|C3F8  ppt
# 37              AIM   ssp370  World  Atmospheric Concentrations|C4F10  ppt
# 38              AIM   ssp370  World  Atmospheric Concentrations|C5F12  ppt
# 39              AIM   ssp370  World  Atmospheric Concentrations|C6F14  ppt
# ...             ...      ...    ...                               ...  ...
# 1285  REMIND-MAGPIE   ssp585  World    Atmospheric Concentrations|N2O  ppb
# 1286  REMIND-MAGPIE   ssp585  World    Atmospheric Concentrations|NF3  ppt
# 1287  REMIND-MAGPIE   ssp585  World    Atmospheric Concentrations|SF6  ppt
# 1288  REMIND-MAGPIE   ssp585  World  Atmospheric Concentrations|SO2F2  ppt
# 1289  REMIND-MAGPIE   ssp585  World  Atmospheric Concentrations|cC4F8  ppt
#
# ...

# %%
df['Scenario'].str.startswith('historical')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1550     True
# 1551     True
# 1552     True
# 1553     True
# 1554     True
# Name: Scenario, Length: 1555, dtype: bool

# %%
reduced = df[(df['Region']=='World')&(df['Mip_Era']=='CMIP6')&~(df['Scenario'].str.startswith('historical'))]

# %%
reduced.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-5ae05aaa6f18> in <module>
# ----> 1 reduced.unique()
#
# c:\users\mencsm\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
